# %%
import pandas as pd
import matplotlib.pyplot as plt

df1=pd.read_csv('column_2C_weka.csv')      #Reading CSV file
df1.head()
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
import pandas as pd
import matplotlib.pyplot as plt

df2=pd.read_csv('column_3C_weka.csv')      #Reading CSV file
df2.head()
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis   class
# 0      98.672917                 -0.254400  Hernia
# 1     114.405425                  4.564259  Hernia
# 2     105.985135                 -3.530317  Hernia
# 3     101.868495                 11.211523  Hernia
# 4     108.168725                  7.918501  Hernia

# %%
df1.shape
# Out:
# (310, 7)

# %%
df2.shape
# Out:
# (310, 7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
# pelvic_incidence            310 non-null float64
# pelvic_tilt_numeric         310 non-null float64
# lumbar_lordosis_angle       310 non-null float64
# sacral_slope                310 non-null float64
# pelvic_radius               310 non-null float64
# degree_spondylolisthesis    310 non-null float64
# class                       310 non-null object
# dtypes: float64(6), object(1)
# memory usage: 17.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
# pelvic_incidence            310 non-null float64
# pelvic_tilt_numeric         310 non-null float64
# lumbar_lordosis_angle       310 non-null float64
# sacral_slope                310 non-null float64
# pelvic_radius               310 non-null float64
# degree_spondylolisthesis    310 non-null float64
# class                       310 non-null object
# dtypes: float64(6), object(1)
# memory usage: 17.0+ KB

# %%
df1.describe()
# Out:
#        pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# count        310.000000           310.000000             310.000000
# mean          60.496653            17.542822              51.930930
# std           17.236520            10.008330              18.554064
# min           26.147921            -6.554948              14.000000
# 25%           46.430294            10.667069              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.877696            22.120395              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# 25%       33.347122     110.709196                  1.603727
# 50%       42.404912     118.268178                 11.767934
# 75%       52.695888     125.467674                 41.287352
# max      121.429566     163.071041                418.543082

# %%
df2.describe()
# Out:
#        pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# count        310.000000           310.000000             310.000000
# mean          60.496653            17.542822              51.930930
# std           17.236520            10.008330              18.554064
# min           26.147921            -6.554948              14.000000
# 25%           46.430294            10.667069              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.877696            22.120395              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# 25%       33.347122     110.709196                  1.603727
# 50%       42.404912     118.268178                 11.767934
# 75%       52.695888     125.467674                 41.287352
# max      121.429566     163.071041                418.543082

# %%
df1['class'].unique()
# Out:
# array(['Abnormal', 'Normal'], dtype=object)

# %%
df1['class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
df2['class'].unique()
# Out:
# array(['Hernia', 'Spondylolisthesis', 'Normal'], dtype=object)

# %%
df2['class'].value_counts()
# Out:
# Spondylolisthesis    150
# Normal               100
# Hernia                60
# Name: class, dtype: int64

# %%
df1.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt_numeric', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis', 'class'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt_numeric', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis', 'class'],
#       dtype='object')

# %%
df=pd.concat([df1,df2])
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
df.shape
# Out:
# (620, 7)

# %%
df['class'].unique()
# Out:
# array(['Abnormal', 'Normal', 'Hernia', 'Spondylolisthesis'], dtype=object)

# %%
df.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt_numeric', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis', 'class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620 entries, 0 to 309
# Data columns (total 7 columns):
# pelvic_incidence            620 non-null float64
# pelvic_tilt_numeric         620 non-null float64
# lumbar_lordosis_angle       620 non-null float64
# sacral_slope                620 non-null float64
# pelvic_radius               620 non-null float64
# degree_spondylolisthesis    620 non-null float64
# class                       620 non-null object
# dtypes: float64(6), object(1)
# memory usage: 38.8+ KB

# %%
df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# count        620.000000           620.000000             620.000000
# mean          60.496653            17.542822              51.930930
# std           17.222592            10.000243              18.539071
# min           26.147921            -6.554948              14.000000
# 25%           46.426366            10.659859              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.955644            22.181798              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    620.000000     620.000000                620.000000
# mean      42.953831     117.920655                 26.296694
# std       13.412255      13.306616                 37.528676
# min       13.366931      70.082575                -11.058179
# 25%       33.340707     110.708958                  1.594748
# 50%       42.404912     118.268178                 11.767934
# 75%       52.744711     125.480174                 41.422828
# max      121.429566     163.071041                418.543082

# %%
df['class'].value_counts()
# Out:
# Abnormal             210
# Normal               200
# Spondylolisthesis    150
# Hernia                60
# Name: class, dtype: int64

# %%
import seaborn as sb
sb.countplot(df['class'],label="Count")   #or sb.countplot(x='class',data=df)
plt.show()

# %%
import seaborn as sb

g = sb.pairplot(df, hue='class',markers=["o", "s", "D","+"])
plt.show()

# %%
df['class'].unique()
# Out:
# array(['Abnormal', 'Normal', 'Hernia', 'Spondylolisthesis'], dtype=object)

# %%
df.replace({'class':{'Abnormal':0,'Normal':1,'Hernia':2,'Spondylolisthesis':3}},inplace=True)
df['class'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  class
# 0      98.672917                 -0.254400      0
# 1     114.405425                  4.564259      0
# 2     105.985135                 -3.530317      0
# 3     101.868495                 11.211523      0
# 4     108.168725                  7.918501      0

# %%
#Spliting the dataset into a training set and a testing set

x=df.drop('class',axis=1)
y=df['class']

from sklearn.cross_validation import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=5)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (434, 6)
# (434,)
# (186, 6)
# (186,)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#K – Nearest Neighbour (KNN) Classifier

from sklearn.neighbors import KNeighborsClassifier

model_KNN=KNeighborsClassifier().fit(x_train,y_train)
print('Accuracy of K – Nearest Neighbour Classifier is {:.2f}' .format(model_KNN.score(x_test,y_test)))
# Out:
# Accuracy of K – Nearest Neighbour Classifier is 0.44

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression

model_lr=LogisticRegression().fit(x_train,y_train)
print("Accuracy of Logistic Regression is {:.2f}" .format(model_lr.score(x_test,y_test)))
# Out:
# Accuracy of Logistic Regression is 0.55

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

model_rf=RandomForestClassifier().fit(x_train,y_train)
print("Accuracy of Random Forest Classifier is {:.2f}" .format(model_rf.score(x_test,y_test)))
# Out:
# Accuracy of Random Forest Classifier is 0.40

# %%
#Support Vector Machine (SVM) Classifier

from sklearn.svm import SVC

model_svm=SVC().fit(x_train,y_train)
print("Accuracy of Support Vector Machine Classifier is {:.2f}" .format(model_svm.score(x_test,y_test)))
# Out:
# Accuracy of Support Vector Machine Classifier is 0.35

# %%
#Decision Tree Classifier

from sklearn.tree import DecisionTreeClassifier

model_dt=DecisionTreeClassifier().fit(x_train,y_train)
print("Accuracy of Decision Tree Classifier is {:.2f}" .format(model_dt.score(x_test,y_test)))
# Out:
# Accuracy of Decision Tree Classifier is 0.39

# %%
#Gaussian Naive Bayes Classifier

from sklearn.naive_bayes import GaussianNB

model_gnb=GaussianNB().fit(x_train,y_train)
print("Accuracy of Gaussian Naive Bayes Classifier is {:.2f}" .format(model_gnb.score(x_test,y_test)))
# Out:
# Accuracy of Gaussian Naive Bayes Classifier is 0.56

# %%
#Gradient Boosting Regressor 

from sklearn.ensemble import GradientBoostingRegressor

model_gbr=GradientBoostingRegressor().fit(x_train,y_train)
print("Accuracy of Gradient Boosting Regressor is {:.2f}" .format(model_gbr.score(x_test,y_test)))
# Out:
# Accuracy of Gradient Boosting Regressor is -1.02

# %%
#AdaBoost Classifier

from sklearn.ensemble import AdaBoostClassifier

model_ab=AdaBoostClassifier().fit(x_train,y_train)
print("Accuracy of Gradient Boosting Regressor is {:.2f}" .format(model_ab.score(x_test,y_test)))
# Out:
# Accuracy of Gradient Boosting Regressor is 0.55

# %%
#Linear Discriminant Analysis

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

model_lda=LinearDiscriminantAnalysis().fit(x_train,y_train)
print('Accuracy of Linear Discriminant Analysis is {:.2f}' .format(model_lda.score(x_test,y_test)))
# Out:
# Accuracy of Linear Discriminant Analysis is 0.53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
#K – Nearest Neighbour (KNN) Classifier

from sklearn.neighbors import KNeighborsClassifier

# experimenting with different k values on which KNN gives more accurate result
score=[]
k_range=range(1,250)
A_max=0
k_best=1

for k in k_range:
    model_knn=KNeighborsClassifier(n_neighbors=k)
    model_knn.fit(x_train,y_train)
    accu_knn=model_knn.score(x_test,y_test)
    score.append(accu_knn)
    if(A_max<accu_knn):
        A_max=accu_knn
        k_best=k
        
plt.plot(k_range,score)
plt.xlabel('Values of K for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()
 
print('KNN gives Maximum Accuracy is {0} and least value of K for maximum accuracy is {1}' .format(A_max,k_best))
# Out:
# KNN gives Maximum Accuracy is 0.5268817204301075 and least value of K for maximum accuracy is 57
